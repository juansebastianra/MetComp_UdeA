# %% [markdown]
# # Interpolación vía polinomios de Lagrange

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_list=[1,3,5,7,8]
y_list=[5,2,4,1,2]

fig=plt.figure()
ax=plt.axes()
ax.plot(x_list,y_list)
plt.show()

# %%
def Pol
