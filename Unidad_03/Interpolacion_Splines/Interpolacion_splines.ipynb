# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_list = [1,2,5,6,7,8,10,13,17,20,23,24,25,27,27.7,28,29,30]
y_list = [3.0,3.7,3.9,4.2,5.7,6.6,7.1,6.7,4.5,7.0,6.1,5.6,5.8,5.2,4.1,4.3,4.1,3.0]
n = len(x_list)-1 #3/h[] n=3

x = np.zeros(n+1)

a = np.zeros(n+1)
b = np.zeros(n+1)
c = np.zeros(n+1)
d = np.zeros(n+1)

l  = np.zeros(n+1)
mu = np.zeros(n+1)
z  = np.zeros(n+1)

va = np.zeros(n+1)

h = np.zeros(n)


for i in range(0,len(x)):
    x[i] = x_list[i]
    a[i] = y_list[i]

#step 1

for i in range(0,n):
    h[i]=x[i+1]-x[i]


#step 2

for i in range(1,n):
    va[i] = 3/h[i] * (a[i+1]-a[i]) - 3/h[i-1] * (a[i]-a[i-1])
    
#step 3, solucion del sistema de ecuaciones lineales


l[0] = 1
mu[0] = 0
z[0] = 0

for i in range(1,n):
    l[i] = 2*(x[i+1]-x[i-1]) - h[i-1]*mu[i-1]
    mu[i] = h[i]/l[i]
    z[i] = (va[i]-h[i-1]*z[i-1])/l[i]
        
l[n] = 1
z[n] = 0
c[n] = 0

for j in np.arange(n-1,-1,-1):
    c[j] = z[j]-mu[j]*c[j+1]
    b[j] = (a[j+1]-a[j])/h[j] - h[j]*(c[j+1]+2*c[j])/3
    d[j] = (c[j+1]-c[j])/(3*h[j])
    

#print("aj = ",a)
#print("bj = ",b)
#print("cj = ",c)
#print("dj = ",d)
    
x_array = np.linspace(min(x_list),max(x_list),100)
y_real = np.e**(x_array)

y_array = []



for i in range(0,len(x_array)):
    for j in range(0,n):
        if x[j]<=x_array[i]<x[j+1]:
            s = a[j]+b[j]*(x_array[i]-x[j]) + c[j]*(x_array[i]-x[j])**2 + d[j]*(x_array[i]-x[j])**3
            y_array.append(s)
    if x_array[i]==x[n]:
        s = a[n]+b[n]*(x_array[i]-x[n]) + c[n]*(x_array[i]-x[n])**2 + d[n]*(x_array[i]-x[n])**3
        y_array.append(s)

#print(len(y_array))
#print(len(x_array))
fig=plt.figure(figsize=(20,4))
ax=plt.axes()
ax.grid()
ax.plot(x_list,y_list,'*')
ax.plot(x_array,y_array,'-')

plt.show()

# %%
x_list = [0.9,1.3,1.9,2.1,2.6,3.0,3.9,4.4,4.7,5.0,6.0,7.0,8.,9.2,10.5,11.3,11.6,12.,12.6,13.,13.3]
y_list = [1.3,1.5,1.85,2.1,2.6,2.7,2.4,2.15,2.05,2.1,2.25,2.3,2.25,1.95,1.4,0.9,0.7,0.6,0.5,0.4,0.25]
#x_list = [0.9,1.3,1.9]
#y_list = [1.3,1.5,1.85]
n = len(x_list)-1 #3/h[] n=3
print(len(x_list), len(y_list))
x = np.zeros(n+1)

a = np.zeros(n+1)
b = np.zeros(n+1)
c = np.zeros(n+1)
d = np.zeros(n+1)

l  = np.zeros(n+1)
mu = np.zeros(n+1)
z  = np.zeros(n+1)

va = np.zeros(n+1)

h = np.zeros(n)


for i in range(0,len(x)):
    x[i] = x_list[i]
    a[i] = y_list[i]

#step 1

for i in range(0,n):
    h[i]=x[i+1]-x[i]


#step 2

for i in range(1,n):
    va[i] = 3/h[i] * (a[i+1]-a[i]) - 3/h[i-1] * (a[i]-a[i-1])
    
#step 3, solucion del sistema de ecuaciones lineales


l[0] = 1
mu[0] = 0
z[0] = 0

for i in range(1,n):
    l[i] = 2*(x[i+1]-x[i-1]) - h[i-1]*mu[i-1]
    mu[i] = h[i]/l[i]
    z[i] = (va[i]-h[i-1]*z[i-1])/l[i]
        
l[n] = 1
z[n] = 0
c[n] = 0

for j in np.arange(n-1,-1,-1):
    c[j] = z[j]-mu[j]*c[j+1]
    b[j] = (a[j+1]-a[j])/h[j] - h[j]*(c[j+1]+2*c[j])/3
    d[j] = (c[j+1]-c[j])/(3*h[j])
    

print("aj = ",a)
print("bj = ",b)
print("cj = ",c)
print("dj = ",d)
   
x_array = np.linspace(min(x_list),max(x_list),100)
#y_real = np.e**(x_array)

y_array = []

print(len(y_array))
sum=0

for i in range(0,len(x_array)):
    
    for j in range(0,n):
        if x[j]<=x_array[i]<x[j+1]:
            sum=sum+1
            s = a[j]+b[j]*(x_array[i]-x[j]) + c[j]*(x_array[i]-x[j])**2 + d[j]*(x_array[i]-x[j])**3
            y_array.append(s)
    if x_array[i]==x[n]:
        s = a[n]+b[n]*(x_array[i]-x[n]) + c[n]*(x_array[i]-x[n])**2 + d[n]*(x_array[i]-x[n])**3
        y_array.append(s)
print(y_array)
print(sum)        
print(len(x_array))
print(len(y_array))

#print(len(y_array))
#print(len(x_array))
fig=plt.figure(figsize=(20,4))
ax=plt.axes()
ax.grid()
ax.plot(x_list,y_list,'*')
ax.plot(x_array,y_array,'-')

plt.show()
# Out:
# 21 21
# aj =  [ 1.3   1.5   1.85  2.1   2.6   2.7   2.4   2.15  2.05  2.1   2.25  2.3
#   2.25  1.95  1.4   0.9   0.7   0.6   0.5   0.4   0.25]
# bj =  [ 0.53962385  0.4207523   1.08680272  1.29494198  0.59339932 -0.02219115
#  -0.50340603 -0.47707506 -0.07131619  0.26233982  0.08077551  0.01455815
#  -0.13900811 -0.3358341  -0.53182991 -0.73117823 -0.49294865 -0.14133531
